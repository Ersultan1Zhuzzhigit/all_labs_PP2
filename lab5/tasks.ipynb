# %%
import re 


with open("row.txt",'r',encoding='utf8') as file:
    data = file.read()


print("Task 1")
matches = re.findall("a.*b", data)
print(matches)

print("Task 2")
matches = re.findall("a.*bb+|abbb+", data)
print(matches)

print('Task 3')
matches = re.findall("[a-z]_+[a-z]+", data)
print(matches)

print('Task 4')
matches = re.findall(r"[A-Z][a-z]+", data)
print(matches)

print('Task 5')
matches = re.findall(r"a+.b", data)
print(matches)

print("Task 6")
matches=re.sub(r"[., ]",':',data)
print(matches)

print("Task 7")
matches=re.sub(r"_",'',data)
print(matches)

print("Task 8")
print(re.findall(r"[A-Z][^A-Z]*", data))

print("Task 9")
print(re.findall(r"[A-Z][a-z]*",data))
                 
print("Task 10")
matches=re.sub(r"[A-Z]",'_',data)
print(matches)
# Out:
# Task 1
# ['a big apple farm. She saw aab and abbb', 'as a_snake and b_b', 'aaa.b, Aa.b, and A.b', 'ad was b', 'amesLike James, Rob']
# Task 2
# ['a big apple farm. She saw aab and abbb']
# Task 3
# ['a_snake', 'b_bird', 'd_around', 's_is', 'n_example', 'f_text', 'h_underscores']
# Task 4
# ['Alice', 'She', 'There', 'John', 'Mary', 'The', 'Apples', 'Bananas', 'Grapes', 'Aaaa', 'Aa', 'The', 'This', 'Camel', 'Case', 'Words', 'Are', 'Common', 'In', 'Programming', 'First', 'Names', 'Like', 'James', 'Robert', 'Alice']
# Task 5
# ['a b', 'aab', 'abb', 'aaa.b', 'a.b']
# Task 6
# Alice:went:to:a:big:apple:farm::She:saw:aab:and:abbb:animals:::
# There:was:a_snake:and:b_bird:sitting:near:a:lake:::
# John:and:Mary:walked_around:the:farm:::
# The:farmer:had:Apples::Bananas::and:Grapes:::
# Aaaa:b::Aa:b::and:A:b:were:written:on:the:wall:::
# The:road:was:bumpy::dusty::and:long:::
# This_is_an_example_of_text_with_underscores:::
# CamelCaseWordsAreCommonInProgramming:::
# FirstNamesLike:James::Robert::and:Alice:start with uppercase:
# Task 7
# Alice went to a big apple farm. She saw aab and abbb animals.
# There was asnake and bbird sitting near a lake.
# John and Mary walkedaround the farm.
# The farmer had Apples, Bananas, and Grapes.
# Aaaa.b, Aa.b, and A.b were written on the wall.
# The road was bumpy, dusty, and long.
# Thisisanexampleoftextwithunderscores.
# CamelCaseWordsAreCommonInProgramming.
# FirstNamesLike James, Robert, and Alice start with uppercase.
# Task 8
# ['Alice went to a big apple farm. ', 'She saw aab and abbb animals.  \n', 'There was a_snake and b_bird sitting near a lake.  \n', 'John and ', 'Mary walked_around the farm.  \n', 'The farmer had ', 'Apples, ', 'Bananas, and ', 'Grapes.  \n', 'Aaaa.b, ', 'Aa.b, and ', 'A.b were written on the wall.  \n', 'The road was bumpy, dusty, and long.  \n', 'This_is_an_example_of_text_with_underscores.  \n', 'Camel', 'Case', 'Words', 'Are', 'Common', 'In', 'Programming.  \n', 'First', 'Names', 'Like ', 'James, ', 'Robert, and ', 'Alice start\xa0with\xa0uppercase.']
# Task 9
# ['Alice', 'She', 'There', 'John', 'Mary', 'The', 'Apples', 'Bananas', 'Grapes', 'Aaaa', 'Aa', 'A', 'The', 'This', 'Camel', 'Case', 'Words', 'Are', 'Common', 'In', 'Programming', 'First', 'Names', 'Like', 'James', 'Robert', 'Alice']
# Task 10
# _lice went to a big apple farm. _he saw aab and abbb animals.
# _here was a_snake and b_bird sitting near a lake.
# _ohn and _ary walked_around the farm.
# _he farmer had _pples, _ananas, and _rapes.
# _aaa.b, _a.b, and _.b were written on the wall.
# _he road was bumpy, dusty, and long.
# _his_is_an_example_of_text_with_underscores.
# _amel_ase_ords_re_ommon_n_rogramming.
# _irst_ames_ike _ames, _obert, and _lice start with uppercase.
